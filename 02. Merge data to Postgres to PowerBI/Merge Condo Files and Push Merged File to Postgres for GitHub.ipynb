# %%
from sqlalchemy import create_engine
import pandas as pd
import os
import psycopg2

# %%
#Merge Condo files
philly = pd.read_csv("philly_zillow5.csv")
philly['citylabel']='Philadelphia'
philly['State']='Pennsylvania'

yonkers = pd.read_csv("zillow5yonkers_ny.csv")
yonkers['citylabel']='Yonkers'
yonkers['State']='New York'

arlington = pd.read_csv("zillow5Arlington_VA.csv")
arlington['citylabel']='Arlington'
arlington['State']='Virginia'

baltimore = pd.read_csv("zillow5baltimore_md.csv")
baltimore['citylabel']='Baltimore'
baltimore['State']='Maryland'

brooklyn1 = pd.read_csv("zillow5Brooklyn1_NY.csv")
brooklyn1['citylabel']='Brooklyn'
brooklyn1['State']='New York'

brooklyn2 = pd.read_csv("zillow5Brooklyn2_NY.csv")
brooklyn2['citylabel']='Brooklyn'
brooklyn2['State']='New York'

brooklyn3 = pd.read_csv("zillow5Brooklyn3_NY.csv")
brooklyn3['citylabel']='Brooklyn'
brooklyn3['State']='New York'

boston = pd.read_csv("zillow5Boston_MA.csv")
boston['citylabel']='Boston'
boston['State']='Massachusetts'

charlotte = pd.read_csv("zillow5Charlotte_NC.csv")
charlotte['citylabel']='Charlotte'
charlotte['State']='North Carolina'

jerseycity = pd.read_csv("zillow5jersey_city_nj.csv")
jerseycity['citylabel']='Jersey City'
jerseycity['State']='New Jersey'

dc = pd.read_csv("washington_dc_zillow5.csv")
dc['citylabel']='Washington D.C.'
dc['State']='Washington D.C.'
#not a state but would like to label it to compare by region

columbus = pd.read_csv("zillow5Columbus_OH.csv")
columbus['citylabel']='Columbus'
columbus['State']='Ohio'

pittsburgh = pd.read_csv("zillow5Pittsburgh_PA.csv")
pittsburgh['citylabel']='Pittsburgh'
pittsburgh['State']='Pennsylvania'

queens1 = pd.read_csv("zillow5QueensNY.csv")
queens1['citylabel']='Queens'
queens1['State']='New York'

queens2 = pd.read_csv("zillow5Queens2NY.csv")
queens2['citylabel']='Queens'
queens2['State']='New York'

queens3 = pd.read_csv("zillow5Queens3_NY.csv")
queens3['citylabel']='Queens'
queens3['State']='New York'

queens4 = pd.read_csv("zillow5Queens4_NY.csv")
queens4['citylabel']='Queens'
queens4['State']='New York'

queens5 = pd.read_csv("zillow5Queens5_NY.csv")
queens5['citylabel']='Queens'
queens5['State']='New York'

ct = pd.read_csv("zillow5CT.csv")
ct['citylabel']='Connecticut'
ct['State']='Connecticut'
#not a city but would like to label it to compare by region. Bridgeport, CT did not yield enough condos for good comparison.

alexandria=pd.read_csv("zillow5Alexandria_VA.csv")
alexandria['citylabel']='Alexandria'
alexandria['State']='Virginia'

statenisland=pd.read_csv("zillow5StatenIsland_NY.csv")
statenisland['citylabel']='Staten Island'
statenisland['State']='New York'

manhattan1=pd.read_csv("zillow5ManhattanNY.csv")
manhattan1['citylabel']='Manhattan'
manhattan1['State']='New York'

manhattan2=pd.read_csv("zillow5Manhattan2_NY.csv")
manhattan2['citylabel']='Manhattan'
manhattan2['State']='New York'

manhattan3=pd.read_csv("zillow5Manhattan3_NY.csv")
manhattan3['citylabel']='Manhattan'
manhattan3['State']='New York'

manhattan4=pd.read_csv("zillow5Manhattan4_NY.csv")
manhattan4['citylabel']='Manhattan'
manhattan4['State']='New York'

manhattan5=pd.read_csv("zillow5Manhattan5_NY.csv")
manhattan5['citylabel']='Manhattan'
manhattan5['State']='New York'

manhattan6=pd.read_csv("zillow5Manhattan6_NY.csv")
manhattan6['citylabel']='Manhattan'
manhattan6['State']='New York'

manhattan7=pd.read_csv("zillow5Manhattan7_NY.csv")
manhattan7['citylabel']='Manhattan'
manhattan7['State']='New York'

df_list = [philly, yonkers, arlington, baltimore, brooklyn1, brooklyn2, brooklyn3, boston, charlotte,
           jerseycity,dc, columbus,pittsburgh,queens1,queens2,queens3,queens4,queens5,ct,alexandria,
          statenisland,manhattan1,manhattan2,manhattan3,manhattan4,manhattan5,manhattan6,manhattan7]

# Merge all the dataframes in df_list
appended_df = pd.concat(df_list)

# %%
print('Num of rows:', len(appended_df))
print('Num of cols:', len(appended_df.columns))
appended_df.drop_duplicates().tail()
# Out:
# Num of rows: 14641
# Num of cols: 76
#       latitude  longitude timeOnZillow  \
# 663  40.769590  -73.98080     550 days
# 664  40.770200  -73.98280     524 days
# 665  40.784107  -73.94971     548 days
# 666  40.783700  -73.98090     584 days
# 667  40.738860  -73.98775     436 days
#
#                                                    url        zpid  \
# 663  /homedetails/15-Central-Park-W-APT-3F-New-York...    80005482
# 664  /homedetails/15-W-61st-St-6A-New-York-NY-10023...  2077612875
# 665  /homedetails/200-E-95th-St-27B-New-York-NY-101...   300200040
# 666  /homedetails/390-Wea-9C-New-York-NY-10024/2078...  2078370808
# 667  /homedetails/260-Park-Ave-S-APT-9J-New-York-NY...    69524334
#
#      livingAreaValue  zipcode             streetAddress  bathrooms  bedrooms  \
# 663           1987.0    10023  15 Central Park W APT 3F        3.0       2.0
# 664           2029.0    10023          15 W 61st St #6A        3.0       4.0
# ...

# %%
conn = psycopg2.connect(user = "postgres",
                          password = "XXX",
                          host = "127.0.0.1",
                          port = "5432",
                          database = "postgres")

cur = conn.cursor()
# Creating a cursor object using the cursor()
# method
  
# drop table accounts
sql = '''DROP TABLE IF EXISTS condos'''
  
# Executing the query
cur.execute(sql)
  
print("Table dropped !")
# Commit your changes in the database
conn.commit()
# Out:
# Table dropped !

# %%
df = appended_df

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:XXX@localhost:5432@/postgres')
appended_df.to_sql('condos', engine)

# %%
conn.close()

# %%
appended_df.to_csv(r'C:\Desktop\merged.csv', index = False)
